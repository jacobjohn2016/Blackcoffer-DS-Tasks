# %% [markdown]
# # Data Extraction and Text Analysis
#
# ## Objective
#
# Objective of this assignment is to extract some sections (which are mentioned below) from SEC / EDGAR financial reports and perform text analysis to compute variables.
#
# ## Data Extraction

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

import os

# %% [markdown]
# ### Reading in filenames

# %%
cik_list = pd.read_excel('data/cik_list.xlsx')
cik_list.head(5)
# Out:
#     CIK            CONAME   FYRMO      FDATE     FORM  \
# 0  3662  SUNBEAM CORP/FL/  199803 1998-03-06  10-K405
# 1  3662  SUNBEAM CORP/FL/  199805 1998-05-15     10-Q
# 2  3662  SUNBEAM CORP/FL/  199808 1998-08-13  NT 10-Q
# 3  3662  SUNBEAM CORP/FL/  199811 1998-11-12   10-K/A
# 4  3662  SUNBEAM CORP/FL/  199811 1998-11-16  NT 10-Q
#
#                                    SECFNAME
# 0  edgar/data/3662/0000950170-98-000413.txt
# 1  edgar/data/3662/0000950170-98-001001.txt
# 2  edgar/data/3662/0000950172-98-000783.txt
# 3  edgar/data/3662/0000950170-98-002145.txt
# 4  edgar/data/3662/0000950172-98-001203.txt

# %%
cik_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CIK       152 non-null    int64
#  1   CONAME    152 non-null    object
#  2   FYRMO     152 non-null    int64
#  3   FDATE     152 non-null    datetime64[ns]
#  4   FORM      152 non-null    object
#  5   SECFNAME  152 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Downloading Reports

# %%
base_url = "https://www.sec.gov/Archives/"

# %%
# # Don't run this cell --- unless no data
# # download each report and save it

# for index, row in cik_list.iterrows():
#     r = requests.get(base_url + row['SECFNAME'])
#     open('data/reports/' + row['SECFNAME'].split(os.sep)[3], 'wb').write(r.content)

# %% [markdown]
# ## 1. Sentimental Analysis
#
# ### 1.1 Cleaning using Stop Words Lists

# %%
# reading stopwords

StopWords_Auditor = pd.read_csv('data/stopwords/StopWords_Auditor.txt')
StopWords_Currencies = pd.read_csv('data/stopwords/StopWords_Currencies.txt')
StopWords_DatesandNumbers = pd.read_csv('data/stopwords/StopWords_DatesandNumbers.txt')
StopWords_Generic = pd.read_csv('data/stopwords/StopWords_Generic.txt')
StopWords_GenericLong = pd.read_csv('data/stopwords/StopWords_GenericLong.txt')
StopWords_Geographic = pd.read_csv('data/stopwords/StopWords_Geographic.txt')
StopWords_Names = pd.read_csv('data/stopwords/StopWords_Names.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-38-7bd8de527e1b> in <module>
#       2
#       3 StopWords_Auditor = pd.read_csv('data/stopwords/StopWords_Auditor.txt')
# ----> 4 StopWords_Currencies = pd.read_csv('data/stopwords/StopWords_Currencies.txt')
#       5 StopWords_DatesandNumbers = pd.read_csv('data/stopwords/StopWords_DatesandNumbers.txt')
#       6 StopWords_Generic = pd.read_csv('data/stopwords/StopWords_Generic.txt')
#
# ...

# %%
StopWords_Auditor
# Out:
#                     ERNST
# 0                   YOUNG
# 1                DELOITTE
# 2                  TOUCHE
# 3                    KPMG
# 4  PRICEWATERHOUSECOOPERS
# 5         PRICEWATERHOUSE
# 6                 COOPERS

# %%
StopWords_Currencies = pd.read_csv('data/stopwords/StopWords_Currencies.txt', sep = '|')
# Out:
# /Users/jacob1.ext/Codes/Blackcoffer-DS-Tasks/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-42-d27a9a17f86f> in <module>
# ----> 1 StopWords_Currencies = pd.read_csv('data/stopwords/StopWords_Currencies.txt', sep = '  | ')
#
# ...
